# %%
import yaml
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %% [markdown]
# # PRUEBAS def nuild_model

# %%
config_file = '../config/01_experimento.yaml'  

with open(config_file, 'r') as f:
    config = yaml.safe_load(f)

models_config = config.get('models', {})
seed_config = config.get('seed', 42)

print("=== Configuración cargada ===")
print("models_config keys:", models_config.keys())
print("seed_config keys  :", seed_config)
# Out:
# === Configuración cargada ===
# models_config keys: dict_keys(['arbol'])
# seed_config keys  : 42

# %%
def build_model(models_config, seed_config):
    '''
    COnstruye el modelo de bagging con el archivo de configuración
    Args:
        models_config (dict): Configuración para los modelos utilizados
        seed_config (int): Semilla para trazabilidad de los experimentos
    '''
    
    pass

build_model(models_config, seed_config)
